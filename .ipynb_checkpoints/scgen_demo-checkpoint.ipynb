# %%
import numpy as np
import scipy as sp
import scipy.sparse
import pandas as pd
import os
import bbknn

import anndata as ad

import scanpy

import matplotlib.pyplot as plt
import tensorflow as tf
import scgen

import hummingbird as hbdx

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# settings
adata_path = "/data/hbdx/test_classifynder/data/LC__ngs__raw-current.h5ad"
n_features = 2500
#holdout_batches = ["essen_201220_hbdx_pool1_A1", "210208__468_Pool3__hbdx"]
holdout_batches = ["konstanz_201208_hbdx_pool1", "Boston_Pool3"]

model_path = f"./models/batch{n_features}_{'-'.join(holdout_batches)}"
force_training = True


plt.rcParams['figure.figsize'] = [15,10]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
def get_data(adata_path, batch_col="Lab_Multiplexing_pool_ID", cell_col="Gender", condition_col="Diagnosis_Group"):
    adata = hbdx.io.load(adata_path)

    pool_id_mapping = {label:f"pool{i}" for i, label in enumerate(adata.obs.Lab_Multiplexing_pool_ID.unique())}
    adata.obs["Lab_Multiplexing_pool_ID_simple"] = adata.obs.Lab_Multiplexing_pool_ID.map(pool_id_mapping)
    
    
    adata.obs["gender_diagnosis"] = adata.obs.apply(lambda x: x["Gender"]+"__" +x["Diagnosis_Group"], axis=1)
    
    adata.obs["batch"] = adata.obs[batch_col]

    adata.obs["cell_type"] = adata.obs[cell_col] if not cell_col is None else "blood"
    
    adata.obs["condition"] = adata.obs[condition_col]

    adata = adata[adata.obs["Sample_Group"]=="Study"].copy()
    
    return adata

def apply_preprocessing(adata, feature_selection=False, n_top_genes=2000):
    adata = adata.copy()
    adata.raw = adata.copy()
    
    scanpy.pp.calculate_qc_metrics(adata, inplace=True)
    scanpy.pp.normalize_total(adata, target_sum=1e6)
    scanpy.pp.log1p(adata)
    
    scanpy.pp.scale(adata)
    scanpy.pp.highly_variable_genes(adata, n_top_genes=n_top_genes)

    adata = adata[adata.obs.n_genes_by_counts > 5, :]
    
    if feature_selection:
        adata = adata[:, adata.var.highly_variable]
    
    scanpy.tl.pca(adata)
    scanpy.pp.neighbors(adata)
    scanpy.tl.umap(adata)
    
    return adata

# %%
# Load AnnData

adata = get_data(adata_path,
                 batch_col="Lab_Multiplexing_pool_ID", 
                 cell_col=None,#"Gender",
                 condition_col="Diagnosis_Group")
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │ <ipython-input-18-bc22dd899cd1>:3 in <module>                                             │
# │                                                                                           │
# │ /home/mah/code/hummingbird/hummingbird/io/file.py:73 in load                              │
# │                                                                                           │
# │    70 │   NotImplementedError                                                             │
# │    71 │   │   Trying to load a file with an extension we do not have loading code for.    │
# │    72 │   """                                                                             │
# │ ❱  73 │   path = _resolve_path(Path(path))                                                │
# │    74 │                                                                                   │
# │    75 │   # If extension is not overwritten take the one from the path_                   │
# │    76 │   if ext is None:                                                                 │
# │                                                                                           │
# │ /home/mah/code/hummingbird/hummingbird/io/file.py:35 in _resolve_path                     │
# │                                                                                           │
# │    32 │   if len(paths) == 1:                                                             │
# │    33 │   │   return paths[0]  # was unique glob                                          │
# │    34 │                                                                                   │
# │ ❱  35 │   raise FileNotFoundError(                                                        │
# │    36 │   │   f"Was trying to resolve path\n\t{path}*\nbut was ambigious because there ar │
# │    37 │   )                                                                               │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: Was trying to resolve path
#         /data/hbdx/test_classifynder/data/LC__ngs_raw-current*
# but was ambigious because there are no or multiple files that fit the glob.

# %%
#batches
print(adata.obs.batch.value_counts())
# Out:
# Thorax_Set1                   92
# Thorax_Set2                   92
# Thorax_Pool1_D1               87
# essen_210104_hbdx_pool2_A2    86
# essen_201220_hbdx_pool1_A1    86
# Thorax_Pool2_D2               85
# Boston_Pool4                  82
# Boston_Pool1                  80
# Boston_Pool2                  79
# 210122__468_Pool6__hbdx       79
# Boston_Pool6                  77
# Boston_Pool3                  76
# Boston_Pool5                  75
# konstanz_201208_hbdx_pool1    68
# konstanz_201218_hbdx_pool2    68
# GF_Pool1_B1                   55
# GF_Pool2_B2                   55
# GF_Set2                       52
# ThoraxRespondr_Pool2          49
# 210129__471_Pool3__hbdx       49
# ThoraxRespondr_Pool1          48
# 210202__471_Pool4__hbdx       43
# 210119__468_Pool5__hbdx       38
# Konstanz_Pool1                27
# 210208__468_Pool3__hbdx       23
# 210128__468_Pool4__hbdx       18
# Kempten_Pool1                 11
# Kempten_Pool2                 10
# Name: batch, dtype: int64

# %%
adata_train = apply_preprocessing(adata[~adata.obs.batch.isin(holdout_batches), :], 
                                  feature_selection=True, 
                                  n_top_genes=n_features)
# Out:
# WARNING: You’re trying to run this on 2500 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
adata_test = apply_preprocessing(adata[adata.obs.batch.isin(holdout_batches), :], 
                                 feature_selection=False)
# Out:
# WARNING: You’re trying to run this on 456553 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
adata_test = adata_test[:, adata_train.var_names]

# %%
scanpy.pl.umap(adata_train, color=["Lab_Multiplexing_pool_ID"], ncols=1, size=60)

# %%
# train / load the VAE
network = scgen.VAEArithKeras(x_dimension= n_features, 
                              model_path=model_path, 
                              z_dimension=100, 
                              alpha=0.5, 
                              learning_rate=0.001,
                              dropout_rate=0.5)

if os.path.exists(model_path) and not force_training:
    network.restore_model()# need h5py version 2.10 for this !!!!
else:
    network.train(train_data=adata_train, n_epochs=100)
# Out:
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 2500)              0
# _________________________________________________________________
# encoder (Model)              (None, 100)               2806600
# _________________________________________________________________
# decoder (Model)              (None, 2500)              2728900
# =================================================================
# Total params: 5,535,500
# Trainable params: 5,529,100
# Non-trainable params: 6,400
# _________________________________________________________________
# Epoch 1/100
# 1546/1546 [==============================] - 3s 2ms/step - loss: 1664.7948 - kl_loss: 170.6165 - recon_loss: 1579.4866
# Epoch 2/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1317.9992 - kl_loss: 153.1122 - recon_loss: 1241.4434
# Epoch 3/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1209.3062 - kl_loss: 138.2535 - recon_loss: 1140.1794
# Epoch 4/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1155.4494 - kl_loss: 125.0888 - recon_loss: 1092.9050
# Epoch 5/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1121.8812 - kl_loss: 115.1574 - recon_loss: 1064.3026
# Epoch 6/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1100.4349 - kl_loss: 110.5325 - recon_loss: 1045.1686
# Epoch 7/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1079.4437 - kl_loss: 101.7768 - recon_loss: 1028.5553
# Epoch 8/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1063.4611 - kl_loss: 97.4999 - recon_loss: 1014.7109
# Epoch 9/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1054.8107 - kl_loss: 95.9293 - recon_loss: 1006.8459
# Epoch 10/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1045.1952 - kl_loss: 91.6682 - recon_loss: 999.3613
# Epoch 11/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1034.4910 - kl_loss: 89.5024 - recon_loss: 989.7397
# Epoch 12/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1031.0223 - kl_loss: 85.8477 - recon_loss: 988.0984
# Epoch 13/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1018.6391 - kl_loss: 84.2070 - recon_loss: 976.5356
# Epoch 14/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1012.6006 - kl_loss: 83.3899 - recon_loss: 970.9056
# Epoch 15/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1007.7409 - kl_loss: 82.5281 - recon_loss: 966.4766
# Epoch 16/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 1001.8679 - kl_loss: 78.9683 - recon_loss: 962.3837
# Epoch 17/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 994.9682 - kl_loss: 77.6536 - recon_loss: 956.1414
# Epoch 18/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 988.7742 - kl_loss: 77.1300 - recon_loss: 950.2092
# Epoch 19/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 986.6086 - kl_loss: 75.6306 - recon_loss: 948.7932
# Epoch 20/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 981.2339 - kl_loss: 74.6992 - recon_loss: 943.8843
# Epoch 21/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 978.9489 - kl_loss: 72.3098 - recon_loss: 942.7941
# Epoch 22/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 976.1096 - kl_loss: 74.1529 - recon_loss: 939.0331
# Epoch 23/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 975.7823 - kl_loss: 73.2833 - recon_loss: 939.1407
# Epoch 24/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 967.1904 - kl_loss: 71.6010 - recon_loss: 931.3899
# Epoch 25/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 968.0806 - kl_loss: 69.8333 - recon_loss: 933.1641
# Epoch 26/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 959.9680 - kl_loss: 69.6354 - recon_loss: 925.1503
# Epoch 27/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 958.4800 - kl_loss: 68.7628 - recon_loss: 924.0986
# Epoch 28/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 953.4029 - kl_loss: 67.9023 - recon_loss: 919.4518
# Epoch 29/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 956.8226 - kl_loss: 66.5026 - recon_loss: 923.5714
# Epoch 30/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 950.3670 - kl_loss: 67.1962 - recon_loss: 916.7690
# Epoch 31/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 946.3093 - kl_loss: 66.2329 - recon_loss: 913.1928
# Epoch 32/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 941.9743 - kl_loss: 65.0228 - recon_loss: 909.4628
# Epoch 33/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 942.1535 - kl_loss: 63.7836 - recon_loss: 910.2617
# Epoch 34/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 940.6056 - kl_loss: 63.3924 - recon_loss: 908.9094
# Epoch 35/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 940.8675 - kl_loss: 64.2899 - recon_loss: 908.7226
# Epoch 36/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 939.4223 - kl_loss: 64.1132 - recon_loss: 907.3657
# Epoch 37/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 936.7368 - kl_loss: 62.3223 - recon_loss: 905.5754
# Epoch 38/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 932.7131 - kl_loss: 62.1982 - recon_loss: 901.6138
# Epoch 39/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 931.4410 - kl_loss: 62.4145 - recon_loss: 900.2336
# Epoch 40/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 932.5807 - kl_loss: 61.4033 - recon_loss: 901.8790
# Epoch 41/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 927.8468 - kl_loss: 60.9367 - recon_loss: 897.3784
# Epoch 42/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 927.1975 - kl_loss: 60.2845 - recon_loss: 897.0551
# Epoch 43/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 925.7900 - kl_loss: 60.0923 - recon_loss: 895.7440
# Epoch 44/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 922.1889 - kl_loss: 60.1795 - recon_loss: 892.0992
# Epoch 45/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 924.8970 - kl_loss: 58.3360 - recon_loss: 895.7291
# Epoch 46/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 920.5368 - kl_loss: 58.2969 - recon_loss: 891.3882
# Epoch 47/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 919.7503 - kl_loss: 58.5307 - recon_loss: 890.4848
# Epoch 48/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 922.2861 - kl_loss: 59.8982 - recon_loss: 892.3371
# Epoch 49/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 917.7072 - kl_loss: 57.3910 - recon_loss: 889.0118
# Epoch 50/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 912.2731 - kl_loss: 57.6387 - recon_loss: 883.4537
# Epoch 51/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 915.2951 - kl_loss: 57.4468 - recon_loss: 886.5718
# Epoch 52/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 913.7879 - kl_loss: 57.4155 - recon_loss: 885.0801
# Epoch 53/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 912.2599 - kl_loss: 57.2445 - recon_loss: 883.6375
# Epoch 54/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 914.9663 - kl_loss: 56.7021 - recon_loss: 886.6151
# Epoch 55/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 911.7997 - kl_loss: 56.8484 - recon_loss: 883.3754
# Epoch 56/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 911.1138 - kl_loss: 56.3872 - recon_loss: 882.9203
# Epoch 57/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 903.3640 - kl_loss: 55.4469 - recon_loss: 875.6406
# Epoch 58/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 908.4494 - kl_loss: 55.8150 - recon_loss: 880.5419
# Epoch 59/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 905.0753 - kl_loss: 55.7659 - recon_loss: 877.1923
# Epoch 60/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 905.4401 - kl_loss: 54.3567 - recon_loss: 878.2617
# Epoch 61/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 901.0742 - kl_loss: 54.3783 - recon_loss: 873.8850
# Epoch 62/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 904.7765 - kl_loss: 54.6959 - recon_loss: 877.4288
# Epoch 63/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 902.1008 - kl_loss: 53.8397 - recon_loss: 875.1810
# Epoch 64/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 902.2069 - kl_loss: 54.8121 - recon_loss: 874.8008
# Epoch 65/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 899.8638 - kl_loss: 51.9495 - recon_loss: 873.8890
# Epoch 66/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 898.4180 - kl_loss: 52.9577 - recon_loss: 871.9392
# Epoch 67/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 900.0114 - kl_loss: 53.4978 - recon_loss: 873.2626
# Epoch 68/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 897.4136 - kl_loss: 52.6517 - recon_loss: 871.0877
# Epoch 69/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 894.2658 - kl_loss: 52.1302 - recon_loss: 868.2005
# Epoch 70/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 896.5444 - kl_loss: 52.7065 - recon_loss: 870.1912
# Epoch 71/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 893.5005 - kl_loss: 51.8513 - recon_loss: 867.5750
# Epoch 72/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 895.0812 - kl_loss: 51.5851 - recon_loss: 869.2886
# Epoch 73/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 894.2143 - kl_loss: 51.1680 - recon_loss: 868.6305
# Epoch 74/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 893.5322 - kl_loss: 51.4441 - recon_loss: 867.8101
# Epoch 75/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 894.3571 - kl_loss: 51.5759 - recon_loss: 868.5692
# Epoch 76/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 892.6348 - kl_loss: 51.1679 - recon_loss: 867.0508
# Epoch 77/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 891.9415 - kl_loss: 50.3708 - recon_loss: 866.7562
# Epoch 78/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 892.3151 - kl_loss: 50.4952 - recon_loss: 867.0675
# Epoch 79/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 888.9409 - kl_loss: 50.8842 - recon_loss: 863.4988
# Epoch 80/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 892.0105 - kl_loss: 50.1362 - recon_loss: 866.9423
# Epoch 81/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 889.5735 - kl_loss: 50.1712 - recon_loss: 864.4880
# Epoch 82/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 889.9043 - kl_loss: 50.9308 - recon_loss: 864.4390
# Epoch 83/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 887.7220 - kl_loss: 50.1355 - recon_loss: 862.6541
# Epoch 84/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 888.5567 - kl_loss: 50.2439 - recon_loss: 863.4348
# Epoch 85/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 889.2028 - kl_loss: 50.0430 - recon_loss: 864.1813
# Epoch 86/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 885.8935 - kl_loss: 49.7641 - recon_loss: 861.0113
# Epoch 87/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 886.1793 - kl_loss: 49.6082 - recon_loss: 861.3753
# Epoch 88/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 885.2936 - kl_loss: 49.7070 - recon_loss: 860.4401
# Epoch 89/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 885.8169 - kl_loss: 49.2925 - recon_loss: 861.1706
# Epoch 90/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 887.2293 - kl_loss: 49.3041 - recon_loss: 862.5773
# Epoch 91/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 886.9757 - kl_loss: 49.5720 - recon_loss: 862.1897
# Epoch 92/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 885.7168 - kl_loss: 49.4980 - recon_loss: 860.9677
# Epoch 93/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 883.0335 - kl_loss: 49.4528 - recon_loss: 858.3070
# Epoch 94/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 883.2716 - kl_loss: 49.1977 - recon_loss: 858.6727
# Epoch 95/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 881.6608 - kl_loss: 49.0065 - recon_loss: 857.1575
# Epoch 96/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 882.0117 - kl_loss: 49.2158 - recon_loss: 857.4037
# Epoch 97/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 882.3050 - kl_loss: 49.5810 - recon_loss: 857.5145
# Epoch 98/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 881.0217 - kl_loss: 48.7050 - recon_loss: 856.6693
# Epoch 99/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 881.2484 - kl_loss: 48.3937 - recon_loss: 857.0515
# Epoch 100/100
# 1546/1546 [==============================] - 2s 1ms/step - loss: 878.5104 - kl_loss: 48.3425 - recon_loss: 854.3392

# %%
train_log = pd.read_csv("/home/tos/code/classifynder/csv_logger.log")
train_log.iloc[:,1:].plot()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">&lt;</span><span style="color: #ff00ff; text-decoration-color: #ff00ff; font-weight: bold">AxesSubplot:</span><span style="font-weight: bold">&gt;</span>
# </pre>

# %%
corrected_train =  scgen.batch_removal(network, 
                                       adata_train, 
                                       batch_key="batch", 
                                       cell_label_key="cell_type")
corrected_train.raw = adata_train

# %%
scanpy.pp.neighbors(corrected_train)
scanpy.tl.umap(corrected_train)
scanpy.pl.umap(corrected_train, color=[
    "batch",
    "cell_type",
    "Diagnosis_Group", 
    "Diagnosis_Group_sub",
    "TumStage",
    "Age",
    "Packyears", 
    "ProjectName", 
    "Site_Clinic",
    "Gender"
], ncols=2,frameon=False, use_raw=False)

# %%
scanpy.pl.umap(adata_test, color=["batch","cell_type"], ncols=1,frameon=True)
# Out:
# /home/tos/conda/envs/hbdx/lib/python3.7/site-packages/anndata/_core/anndata.py:1208: ImplicitModificationWarning: Initializing view as actual.
#   "Initializing view as actual.", ImplicitModificationWarning
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.

# %%
#adata_test_unlab = adata_test.copy()

#adata_test_unlab.obs.cell_type = 0
#print(adata_test_unlab.obs.cell_type.value_counts())
corrected_test = scgen.batch_removal(network, adata_test, batch_key="batch", )
corrected_test.raw = adata_test

#corrected_test.obs.cell_type = adata_test.obs.cell_type

# %%
corrected_merged = ad.concat([corrected_train, corrected_test])

# %%
holdout_batches
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #008000; text-decoration-color: #008000">'konstanz_201208_hbdx_pool1'</span>, <span style="color: #008000; text-decoration-color: #008000">'Boston_Pool3'</span><span style="font-weight: bold">]</span>
# </pre>

# %%
scanpy.pp.neighbors(corrected_merged)
scanpy.tl.umap(corrected_merged)
scanpy.pl.umap(corrected_merged, color=["batch","cell_type","condition"], ncols=1,frameon=False, use_raw=False)
# Out:
# WARNING: You’re trying to run this on 2500 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
scanpy.pl.umap(corrected_merged, color=["batch"], groups=holdout_batches, ncols=1,frameon=False)

# %%
train_adata_cancer = corrected_train[corrected_train.obs.condition=="CaseLC"]
train_adata_control = corrected_train[corrected_train.obs.condition=="Control"]

# %%
print(train_adata_cancer)
print(train_adata_control)
# Out:
# View of AnnData object with n_obs × n_vars = 832 × 2500
#     obs: 'subID', 'Site_Clinic', 'enrollment', 'ProjectName', 'ProjectID', 'Visit', 'Cohort', 'Gender', 'Age', 'Age_binned_5', 'Age_binned_10', 'Ethnicity', 'Smoking', 'Smoking_Enrollment', 'Packyears', 'Packyears_binned_5', 'Packyears_binned_10', 'Biopsy', 'BiopsyDt', 'Surgery', 'SurgeryDt', 'BloodDrawDt', 'Order_Exam', 'DiagnosisDt', 'Metastasis', 'TumTNM', 'TumGrade', 'TumStage', 'TumStageSimp', 'TumLocation', 'TumICD_O', 'TumICD_10', 'Diagnosis', 'Diagnosis_Group', 'Diagnosis_Group_sub', 'Diagnosis_Group_by_Dates', 'PriorCancer', 'PriorCancerType', 'RADS_enrollment', 'OtherD_Allergies', 'OtherD_Arthritis', 'OtherD_Asthma', 'OtherD_COPD', 'OtherD_Diabetes', 'OtherD_Depression', 'OtherD_HighBloodPressure', 'OtherD_Hyperlipidemia', 'Med_AntiCoagulants', 'Med_AntiInflammatory', 'Med_AntiDepressant', 'CritMet', 'CritMet_Stg12', 'BldRepDt', 'Ery', 'Ery_Unit', 'Ery_microliter', 'Ery_Flag', 'Leuko', 'Leuko_Unit', 'Leuko_microliter', 'Leuko_Flag', 'Thrombo', 'Thrombo_Unit', 'Thrombo_microliter', 'Thrombo_Flag', 'Neut', 'Neut_Unit', 'Neut_microliter', 'Neut_Flag', 'Eos', 'Eos_Unit', 'Eos_microliter', 'Eos_Flag', 'Neut_percent', 'Neut_percent_Flag', 'Eos_percent', 'Eos_percent_Flag', 'Baso_percent', 'Baso_Flag', 'Lymph_percent', 'Lymph_Flag', 'Mono_percent', 'Mono_Flag', 'HBDx_ID', 'ColDevice_ID', 'ColDevice_AliquotID', 'ColDevice_nMeas', 'ColDevice_Type', 'ColDevice_FillingLevel_prov', 'ColDevice_FillingLevel', 'ColDevice_Weight', 'ColDevice_Expire', 'Lab_RNA_extr_protocol', 'Lab_RNA_amount', 'RIN', 'Lab_spike_in_used', 'Lab_spike_in_list', 'Lab_Blocking_State', 'Lab_Blocking_Protocol', 'Lab_Blocking_blocked_miRs', 'Lab_Library_Protocol', 'Lab_Library_Purification', 'flow_cell_code_All', 'flow_cell_code_1', 'flow_cell_code_2', 'flow_cell_code_3', 'flow_cell_code_4', 'flow_cell_code_5', 'flow_cell_code_6', 'Lab_FlowCell_Lot_All', 'Lab_FlowCell_Lot_1', 'Lab_FlowCell_Lot_2', 'Lab_FlowCell_Lot_3', 'Lab_FlowCell_Lot_4', 'Lab_FlowCell_Lot_5', 'Lab_FlowCell_Lot_6', 'Lab_Cartridge_Lot_All', 'Lab_Cartridge_Lot_1', 'Lab_Cartridge_Lot_2', 'Lab_Cartridge_Lot_3', 'Lab_Cartridge_Lot_4', 'Lab_Cartridge_Lot_5', 'Lab_Cartridge_Lot_6', 'Lab_Box1_Lot', 'Lab_Box2_Lot', 'Site_Measurement', 'FlowCell_IDs', 'FlowCell_nr_of_flow_cells', 'Sequencer', 'Sequencer_names', 'Date_of_pool', 'Lab_Multiplexing_pool_ID', 'Lab_Multiplexing_pool_ID_simple', 'index_barcode', 'FileName', 'Sample_Group', 'HBDx_ID_core', 'gender_diagnosis', 'batch', 'cell_type', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     uns: 'neighbors', 'umap', 'batch_colors', 'cell_type_colors', 'Diagnosis_Group_colors', 'Diagnosis_Group_sub_colors', 'TumStage_colors', 'ProjectName_colors', 'Site_Clinic_colors'
#     obsm: 'latent', 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'
# View of AnnData object with n_obs × n_vars = 675 × 2500
#     obs: 'subID', 'Site_Clinic', 'enrollment', 'ProjectName', 'ProjectID', 'Visit', 'Cohort', 'Gender', 'Age', 'Age_binned_5', 'Age_binned_10', 'Ethnicity', 'Smoking', 'Smoking_Enrollment', 'Packyears', 'Packyears_binned_5', 'Packyears_binned_10', 'Biopsy', 'BiopsyDt', 'Surgery', 'SurgeryDt', 'BloodDrawDt', 'Order_Exam', 'DiagnosisDt', 'Metastasis', 'TumTNM', 'TumGrade', 'TumStage', 'TumStageSimp', 'TumLocation', 'TumICD_O', 'TumICD_10', 'Diagnosis', 'Diagnosis_Group', 'Diagnosis_Group_sub', 'Diagnosis_Group_by_Dates', 'PriorCancer', 'PriorCancerType', 'RADS_enrollment', 'OtherD_Allergies', 'OtherD_Arthritis', 'OtherD_Asthma', 'OtherD_COPD', 'OtherD_Diabetes', 'OtherD_Depression', 'OtherD_HighBloodPressure', 'OtherD_Hyperlipidemia', 'Med_AntiCoagulants', 'Med_AntiInflammatory', 'Med_AntiDepressant', 'CritMet', 'CritMet_Stg12', 'BldRepDt', 'Ery', 'Ery_Unit', 'Ery_microliter', 'Ery_Flag', 'Leuko', 'Leuko_Unit', 'Leuko_microliter', 'Leuko_Flag', 'Thrombo', 'Thrombo_Unit', 'Thrombo_microliter', 'Thrombo_Flag', 'Neut', 'Neut_Unit', 'Neut_microliter', 'Neut_Flag', 'Eos', 'Eos_Unit', 'Eos_microliter', 'Eos_Flag', 'Neut_percent', 'Neut_percent_Flag', 'Eos_percent', 'Eos_percent_Flag', 'Baso_percent', 'Baso_Flag', 'Lymph_percent', 'Lymph_Flag', 'Mono_percent', 'Mono_Flag', 'HBDx_ID', 'ColDevice_ID', 'ColDevice_AliquotID', 'ColDevice_nMeas', 'ColDevice_Type', 'ColDevice_FillingLevel_prov', 'ColDevice_FillingLevel', 'ColDevice_Weight', 'ColDevice_Expire', 'Lab_RNA_extr_protocol', 'Lab_RNA_amount', 'RIN', 'Lab_spike_in_used', 'Lab_spike_in_list', 'Lab_Blocking_State', 'Lab_Blocking_Protocol', 'Lab_Blocking_blocked_miRs', 'Lab_Library_Protocol', 'Lab_Library_Purification', 'flow_cell_code_All', 'flow_cell_code_1', 'flow_cell_code_2', 'flow_cell_code_3', 'flow_cell_code_4', 'flow_cell_code_5', 'flow_cell_code_6', 'Lab_FlowCell_Lot_All', 'Lab_FlowCell_Lot_1', 'Lab_FlowCell_Lot_2', 'Lab_FlowCell_Lot_3', 'Lab_FlowCell_Lot_4', 'Lab_FlowCell_Lot_5', 'Lab_FlowCell_Lot_6', 'Lab_Cartridge_Lot_All', 'Lab_Cartridge_Lot_1', 'Lab_Cartridge_Lot_2', 'Lab_Cartridge_Lot_3', 'Lab_Cartridge_Lot_4', 'Lab_Cartridge_Lot_5', 'Lab_Cartridge_Lot_6', 'Lab_Box1_Lot', 'Lab_Box2_Lot', 'Site_Measurement', 'FlowCell_IDs', 'FlowCell_nr_of_flow_cells', 'Sequencer', 'Sequencer_names', 'Date_of_pool', 'Lab_Multiplexing_pool_ID', 'Lab_Multiplexing_pool_ID_simple', 'index_barcode', 'FileName', 'Sample_Group', 'HBDx_ID_core', 'gender_diagnosis', 'batch', 'cell_type', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     uns: 'neighbors', 'umap', 'batch_colors', 'cell_type_colors', 'Diagnosis_Group_colors', 'Diagnosis_Group_sub_colors', 'TumStage_colors', 'ProjectName_colors', 'Site_Clinic_colors'
#     obsm: 'latent', 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
pred, delta = network.predict(adata=train_adata_cancer, 
                              conditions={"ctrl": "Control", "stim": "CaseLC"}, 
                              adata_to_predict=train_adata_control,
                              cell_type_key="cell_type", 
                              condition_key="condition")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #ff0000; text-decoration-color: #ff0000">╭──────────────────────────── </span><span style="color: #800000; text-decoration-color: #800000; font-weight: bold">Traceback </span><span style="color: #bf7f7f; text-decoration-color: #bf7f7f; font-weight: bold">(most recent call last)</span><span style="color: #ff0000; text-decoration-color: #ff0000"> ────────────────────────────╮</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #808000; text-decoration-color: #808000">&lt;ipython-input-679-4435a1f7263b&gt;</span>:<span style="color: #0000ff; text-decoration-color: #0000ff">5</span> in <span style="color: #00ff00; text-decoration-color: #00ff00">&lt;module&gt;</span>                                            <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>                                                                                           <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #bfbf7f; text-decoration-color: #bfbf7f">/home/tos/conda/envs/hbdx/lib/python3.7/site-packages/scgen/models/</span><span style="color: #808000; text-decoration-color: #808000; font-weight: bold">_vae_keras.py</span>:<span style="color: #0000ff; text-decoration-color: #0000ff">324</span> in   <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #00ff00; text-decoration-color: #00ff00">predict</span>                                                                                   <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>                                                                                           <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">321 │   │   </span><span style="color: #0000ff; text-decoration-color: #0000ff">if</span> obs_key == <span style="color: #808000; text-decoration-color: #808000">"all"</span>:                                                        <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">322 │   │   │   </span>ctrl_x = adata[adata.obs[<span style="color: #808000; text-decoration-color: #808000">"condition"</span>] == conditions[<span style="color: #808000; text-decoration-color: #808000">"ctrl"</span>], :]         <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">323 │   │   │   </span>stim_x = adata[adata.obs[<span style="color: #808000; text-decoration-color: #808000">"condition"</span>] == conditions[<span style="color: #808000; text-decoration-color: #808000">"stim"</span>], :]         <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #800000; text-decoration-color: #800000">❱ </span>324 <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">│   │   │   </span>ctrl_x = balancer(ctrl_x, cell_type_key=cell_type_key, condition_key=co <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">325 │   │   │   </span>stim_x = balancer(stim_x, cell_type_key=cell_type_key, condition_key=co <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">326 │   │   </span><span style="color: #0000ff; text-decoration-color: #0000ff">else</span>:                                                                       <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">327 │   │   │   </span>key = <span style="color: #00ffff; text-decoration-color: #00ffff">list</span>(obs_key.keys())[<span style="color: #0000ff; text-decoration-color: #0000ff">0</span>]                                           <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>                                                                                           <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #bfbf7f; text-decoration-color: #bfbf7f">/home/tos/conda/envs/hbdx/lib/python3.7/site-packages/scgen/models/</span><span style="color: #808000; text-decoration-color: #808000; font-weight: bold">util.py</span>:<span style="color: #0000ff; text-decoration-color: #0000ff">172</span> in         <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #00ff00; text-decoration-color: #00ff00">balancer</span>                                                                                  <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>                                                                                           <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">169 │   </span>class_pop = {}                                                                  <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">170 │   </span><span style="color: #0000ff; text-decoration-color: #0000ff">for</span> <span style="color: #00ffff; text-decoration-color: #00ffff">cls</span> <span style="color: #ff00ff; text-decoration-color: #ff00ff">in</span> class_names:                                                         <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">171 │   │   </span>class_pop[<span style="color: #00ffff; text-decoration-color: #00ffff">cls</span>] = adata.copy()[adata.obs[cell_type_key] == <span style="color: #00ffff; text-decoration-color: #00ffff">cls</span>].shape[<span style="color: #0000ff; text-decoration-color: #0000ff">0</span>]     <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span> <span style="color: #800000; text-decoration-color: #800000">❱ </span>172 <span style="color: #7f7f7f; text-decoration-color: #7f7f7f">│   </span>max_number = np.max(<span style="color: #00ffff; text-decoration-color: #00ffff">list</span>(class_pop.values()))                                   <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>
# <span style="color: #ff0000; text-decoration-color: #ff0000">│</span>   <span style="color:
